# %% [markdown]
# This file will make Figure S3 and S4 for the appendix comparing alternative scaling laws using state variable data from data_statevariables.txt and the biomass prediction code biomass.py

# %%
import numpy as np
import pandas as pd
import biomass as bm
from scipy.stats import linregress
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the data
data = pd.read_csv('data_statevariables.csv')

# %%
# Now add a column for predicted numerical biomass data
data['pBnum_2_3'] = np.zeros(len(data))
# Iterate through each row and append the biomass information
for index, row in data.iterrows():
    # Get 2/3
    dtemp = {'S': row['S'], 'N': row['N'], 'E': row['E_2_3']}
    data.loc[index,'pBnum_2_3'] = bm.biomass(dtemp,power=3/2)

# %%
display(data)
# Out:
#     Unnamed: 0                                               Site  \
# 0            0         Point Reyes National Seashore Bishop Pines
# 1            1         Point Reyes National Seashore Bishop Pines
# 2            2                  Hubbard Brook Experimental Forest
# 3            3                        Kellogg Biological Station
# 4            4                        Kellogg Biological Station
# 5            5                        Kellogg Biological Station
# 6            6                    SCBI Large Forest Dynamics Plot
# 7            7  CSIRO permament rainforest plots of North Quee...
# 8            8  CSIRO permament rainforest plots of North Quee...
# 9            9  CSIRO permament rainforest plots of North Quee...
# 10          10  CSIRO permament rainforest plots of North Quee...
# 11          11  CSIRO permament rainforest plots of North Quee...
# 12          12  CSIRO permament rainforest plots of North Quee...
# 13          13  CSIRO permament rainforest plots of North Quee...
# 14          14  CSIRO permament rainforest plots of North Quee...
# 15          15  CSIRO permament rainforest plots of North Quee...
# 16          16  CSIRO permament rainforest plots of North Quee...
# 17          17  CSIRO permament rainforest plots of North Quee...
# 18          18  CSIRO permament rainforest plots of North Quee...
# 19          19  CSIRO permament rainforest plots of North Quee...
# 20          20  CSIRO permament rainforest plots of North Quee...
# 21          21                                               RMBL
# 22          22                                                BCI
# 23          23                                             Cocoli
# 24          24                                            Sherman
# 25          25                                              Pasoh
# 26          26                                      UC Santa Cruz
# 27          27                                             Catuba
# 28          28                                     Harvard Forest
# 29          29                                     Harvard Forest
# 30          30                   Traunstein Forest Dynamics Plot
# 31          31                                             Hawaii
# 32          32                                             Hawaii
# 33          33                                             Hawaii
# 34          34                                             Hawaii
# 35          35                                             Hawaii
#
#                        Plot                        Type             Location   \
# 0                Mt. Vision  Temperate forest community        California USA
# 1                   Bayview  Temperate forest community        California USA
# 2               Watershed 6             Temperate trees     New Hampshire USA
# 3        Deciduous Forest 1             Temperate trees          Michigan USA
# 4        Deciduous Forest 2             Temperate trees          Michigan USA
# 5        Deciduous Forest 3             Temperate trees          Michigan USA
# 6               Front Royal             Temperate trees          Virginia USA
# 7                       EP3              Tropical trees  Queensland Australia
# 8                      EP18              Tropical trees  Queensland Australia
# 9                      EP19              Tropical trees  Queensland Australia
# 10                     EP29              Tropical trees  Queensland Australia
# 11                     EP30              Tropical trees  Queensland Australia
# 12                     EP31              Tropical trees  Queensland Australia
# 13                     EP32              Tropical trees  Queensland Australia
# 14                     EP33              Tropical trees  Queensland Australia
# 15                     EP34              Tropical trees  Queensland Australia
# 16                     EP40              Tropical trees  Queensland Australia
# 17                     EP41              Tropical trees  Queensland Australia
# 18                     EP42              Tropical trees  Queensland Australia
# 19                     EP43              Tropical trees  Queensland Australia
# 20                     EP44              Tropical trees  Queensland Australia
# 21                Belleview      Subalpine meadow flora          Colorado USA
# 22                     CTFS              Tropical trees                Panama
# 23                     CTFS              Tropical trees                Panama
# 24                     CTFS              Tropical trees                Panama
# 25                     CTFS              Tropical trees              Malaysia
# 26                     FERC  Temperate forest community        California USA
# 27                   Catuba              Tropical trees                Brazil
# 28                EMS Tower             Temperate trees     Massachsetts, USA
# 29  Lyford mapped tree plot             Temperate trees     Massachsetts, USA
# 30                      NaN             Temperate trees               Germany
# 31          Volcano (200 y)         Tropical arthropods            Hawaii USA
# 32           Lanai (1500 y)         Tropical arthropods            Hawaii USA
# 33          Kohala (150 ky)         Tropical arthropods            Hawaii USA
# 34         Molokai (1.2 My)         Tropical arthropods            Hawaii USA
# 35              Kauai (4My)         Tropical arthropods            Hawaii USA
#
#     Year            A_ha    S       N             E             B  \
# 0   2012          0.0256   27    1844  2.223879e+06  1.239403e+08
# 1   2012          0.0256   16     486  1.585384e+06  3.879334e+07
# 2   2017           13.23   16   10230  5.532430e+04  1.175971e+05
# 3   2018  0.81 estimated   18     259  1.110548e+04  5.723116e+04
# 4   2018   0.5 estimated   10     172  8.115756e+03  4.363665e+04
# 5   2018  0.35 estimated   13     136  2.820084e+03  1.093614e+04
# 6   2012            25.6   68   29986  1.110233e+07  1.530357e+08
# 7   1973             0.5   67     506  4.074955e+03  1.113186e+04
# 8   1975             0.5   79     452  3.915177e+03  1.133263e+04
# 9   1977             0.5   64     397  2.482458e+03  6.218057e+03
# 10  1981             0.5   49     487  2.634251e+03  5.684631e+03
# 11  1976             0.5   66     552  3.737412e+03  9.528809e+03
# 12  1978             0.5   47     236  2.544609e+03  8.096390e+03
# 13  1983             0.5   51     437  1.887393e+03  4.519255e+03
# 14  1990             0.5   43     307  4.435325e+03  1.584059e+04
# 15  1984             0.5   59     290  3.040910e+03  9.044354e+03
# 16  1998             0.5   48     477  3.859423e+03  1.109537e+04
# 17  1983             0.5   50     369  2.775138e+03  6.739585e+03
# 18  1977             0.5   58     243  2.732479e+03  9.317053e+03
# 19  1984             0.5   59     385  4.151287e+03  1.285602e+04
# 20  1990             0.5   58     443  3.779391e+03  1.081151e+04
# 21  2012          0.0064   31     877  9.178720e+05  1.753214e+07
# 22  1982              50  307  235338  2.394486e+07  4.057236e+08
# 23  1997               2  171    8290  1.717206e+06  2.963648e+07
# 24  1997            5.96  225   24453  2.325982e+06  2.493744e+07
# 25  1985              50  673   55187  2.559037e+06  2.636492e+07
# 26  2006               6   31    8370  1.004622e+07  2.234938e+08
# 27  1999              20  156    1009  1.776010e+04  6.239722e+04
# 28  1993            1.26   15     759  4.953740e+03  1.088094e+04
# 29  1969            2.88   24    3696  1.411013e+05  6.551516e+05
# 30  2016              25   29   15758  4.259937e+05  1.679991e+06
# 31  1997             NaN  167    1909  8.312176e+04  4.242602e+05
# 32  1997             NaN  156    2253  4.121011e+04  1.658381e+05
# 33  1997             NaN  240    6048  8.716836e+04  3.394718e+05
# 34  1997             NaN  227    3865  1.021892e+05  4.135082e+05
# 35  1997             NaN  158    1922  3.581852e+04  1.379167e+05
#
#            E_2_3         B_2_3     pBnum_2_3
# 0   2.223879e+06  9.294502e+08  3.430830e+08
# 1   1.585384e+06  1.950838e+08  3.056069e+08
# 2   5.532430e+04  1.771211e+05  9.502302e+05
# 3   1.110548e+04  1.344667e+05  1.897001e+05
# 4   8.115756e+03  1.048796e+05  1.516009e+05
# 5   2.820084e+03  2.226603e+04  2.958019e+04
# 6   1.110233e+07  5.921821e+08  1.851878e+09
# 7   4.074955e+03  1.929299e+04  2.260922e+04
# 8   3.915177e+03  2.027064e+04  2.114594e+04
# 9   2.482458e+03  1.036229e+04  1.114691e+04
# 10  2.634251e+03  8.668003e+03  1.208480e+04
# 11  3.737412e+03  1.594301e+04  1.906885e+04
# 12  2.544609e+03  1.511690e+04  1.514565e+04
# 13  1.887393e+03  7.595750e+03  7.097924e+03
# 14  4.435325e+03  3.203239e+04  3.429068e+04
# 15  3.040910e+03  1.631810e+04  1.771069e+04
# 16  3.859423e+03  1.994136e+04  2.311463e+04
# 17  2.775138e+03  1.084003e+04  1.466088e+04
# 18  2.732479e+03  1.808258e+04  1.592251e+04
# 19  4.151287e+03  2.376719e+04  2.644934e+04
# 20  3.779391e+03  1.926665e+04  2.179858e+04
# 21  9.178720e+05  8.147420e+07  9.844353e+07
# 22  2.394486e+07  1.913214e+09  2.553872e+09
# 23  1.717206e+06  1.320377e+08  9.740229e+07
# 24  2.325982e+06  8.906301e+07  1.170556e+08
# 25  2.559037e+06  9.617912e+07  8.034390e+07
# 26  1.004622e+07  1.124946e+09  2.517644e+09
# 27  1.776010e+04  1.220465e+05  1.493291e+05
# 28  4.953740e+03  1.655248e+04  4.122650e+04
# 29  1.411013e+05  1.474992e+06  4.961369e+06
# 30  4.259937e+05  3.433256e+06  1.970062e+07
# 31  4.956532e+04  4.242602e+05  6.060764e+05
# 32  2.699172e+04  1.658381e+05  2.285177e+05
# 33  5.894559e+04  3.394718e+05  5.199849e+05
# 34  6.591506e+04  4.135082e+05  7.193355e+05
# 35  2.389382e+04  1.379167e+05  1.966985e+05

# %% [markdown]
# # General plot setup

# %%
# Choose color scheme
cm = 'winter'#'viridis'
# Get max and min species richness for colour scheme
smin = np.min(data['S'])
smax = np.max(data['S'])
# Set up normalization
norm = plt.Normalize(np.log(smin),np.log(smax))
# Get list of site types
stype = data['Type'].unique()
# Make marker list. Has to be same length as stype
mlist = ['s','^','D','o','X']

# %% [markdown]
# # Alternative scaling

# %%
# Figure S2
fig,ax = plt.subplots(figsize=(4,4))

# Plot data
xdata = np.log(data['pBnum_2_3'])
ydata = np.log(data['B_2_3'])

# Loop through each site type to put a different marker
for m,s in zip(mlist,stype):
    inds = data['Type']==s
    ax.scatter(xdata[inds],ydata[inds],marker=m,c=np.log(data['S'][inds]),cmap=cm,norm=norm,edgecolor='0.3')

# Set range
ymin = np.floor(np.min(ydata))
ymax = np.ceil(np.max(ydata))
xmin = np.floor(np.min(xdata))
xmax = np.ceil(np.max(xdata))
# Set range min as min of those
rmin = np.min([ymin,xmin])
rmax = np.max([ymax,xmax])
ax.set_ylim(rmin,rmax)
ax.set_xlim(rmin,rmax)

# Labels
ax.set_xlabel('ln(predicted biomass)')
ax.set_ylabel('ln(observed biomass)')

# Add in R^2 value from regression
lin = linregress(xdata,ydata)
xlin = np.linspace(xmin,xmax)
ax.annotate(r'$R^2 = {:.3f}$'.format(lin[2]**2),(0.73,0.17),xycoords='figure fraction')

# Legend
# Plot a bunch of empty points. Not sure if this is the best way, but it's how I'm doing it!
leg = {}
for m,s in zip(mlist,stype):
    leg[s], = ax.plot([],[],c='0.3',marker=m,linestyle="None")

# Plot 1:1 line at the back and add to legend codes
xrange = np.linspace(rmin,rmax)
leg['1:1'], = ax.plot(xrange,xrange,lw=2,c='0.3',zorder=0)#,label='1:1 line') # Can add this back in
lcodes = np.insert(stype,0,'1:1')

ax.legend([leg[s] for s in lcodes],lcodes,prop={"size":7.3})#,frameon=False)#borderpad=0.0)

# Save
fig.savefig('Figures/figS3.pdf',bbox_inches='tight')

# %%
# Figure S3
fig,ax = plt.subplots(figsize=(4,4))

# Plot data
xdata = data['E_2_3']/data['pBnum_2_3']**(2/3)
ydata = data['E_2_3']/data['B_2_3']**(2/3)
# Loop through each site type to put a different marker
for m,s in zip(mlist,stype):
    inds = data['Type']==s
    ax.scatter(xdata[inds],ydata[inds],marker=m,c=np.log(data['S'][inds]),cmap=cm,norm=norm,edgecolor='0.3')

# Set range
ymin = np.floor(np.min(ydata))
ymax = np.ceil(np.max(ydata))
xmin = np.floor(np.min(xdata))
xmax = np.ceil(np.max(xdata))
# Set range min as min of those
rmin = np.min([ymin,xmin])
rmax = np.max([ymax,xmax])
ax.set_ylim(rmin,rmax)
ax.set_xlim(rmin,rmax)

# Labels
ax.set_xlabel(r'Predicted ratio $E:B^{2/3}$')
ax.set_ylabel(r'Observed ratio $E:B^{2/3}$')

# Add in R^2 value from regression
lin = linregress(xdata,ydata)
xlin = np.linspace(xmin,xmax)
ax.annotate(r'$R^2 = {:.3f}$'.format(lin[2]**2),(0.18,0.82),xycoords='figure fraction')

# Legend
# Plot a bunch of empty points. Not sure if this is the best way, but it's how I'm doing it!
leg = {}
for m,s in zip(mlist,stype):
    leg[s], = ax.plot([],[],c='0.3',marker=m,linestyle="None")
    
# Plot 1:1 line at the back and add to legend codes
xrange = np.linspace(rmin,rmax)
leg['1:1'], = ax.plot(xrange,xrange,lw=2,c='0.3',zorder=0)#,label='1:1 line') # Can add this back in
lcodes = np.insert(stype,0,'1:1')

ax.legend([leg[s] for s in lcodes],lcodes,prop={"size":7.3})#,frameon=False#borderpad=0.0)

# Save
fig.savefig('Figures/figS4.pdf',bbox_inches='tight')
